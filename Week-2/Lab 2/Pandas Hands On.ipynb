# %% [markdown]
# # Pandas Tutorial
#
#
# ---

# %%
import pandas as pd
import numpy as np

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0])
data
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
print(data[0],type(data[0]))
# Out:
# 0.25 <class 'numpy.float64'>

# %%
print(data[2:],type(data[2:]))
# Out:
# 2    0.75
# 3    1.00
# dtype: float64 <class 'pandas.core.series.Series'>

# %%
print(data.values,type(data.values))
# Out:
# [0.25 0.5  0.75 1.  ] <class 'numpy.ndarray'>

# %%
print(data.index,type(data.index))
# Out:
# RangeIndex(start=0, stop=4, step=1) <class 'pandas.core.indexes.range.RangeIndex'>

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index=['a', 'b', 'c', 'd'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
data['a']
# Out:
# 0.25

# %%
data = pd.Series([0.25, 0.5, 0.75, 1.0], index=[1, 3, 4, 2])
data
# Out:
# 1    0.25
# 3    0.50
# 4    0.75
# 2    1.00
# dtype: float64

# %%
data[4]
# Out:
# 0.75

# %% [markdown]
# ### Series and Python Dictionaries
#
# Pandas Series and Python Dictionaries are close semantically: mappping keys to values. However, the implementation of Pandas series is usually more efficient than dictionaries in the context of data science. Naturally, Series can be contructed from dictionaries.

# %%
population_dict = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 19651127,
                   'Florida': 19552860,
                   'Illinois': 12882135}
population = pd.Series(population_dict)

# %%
print(population_dict,type(population_dict))
print(population,type(population))
# Out:
# {'California': 38332521, 'Texas': 26448193, 'New York': 19651127, 'Florida': 19552860, 'Illinois': 12882135} <class 'dict'>
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
population['California']
# Out:
# 38332521

# %%
# Label Sclicing 

population['California': 'Illinois']
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population['California': ]
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
population['California': 'New York']
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# dtype: int64

# %% [markdown]
# ## Pandas DataFrames

# %%
area = pd.Series( {'California': 423967, 'Texas': 695662, 'New York': 141297, 'Florida': 170312, 'Illinois': 149995})
population = pd.Series({'California': 38332521, 'Texas': 26448193, 'New York': 19651127, 'Florida': 19552860, 'Illinois': 12882135})

# %%
states = pd.DataFrame({'Population': population, 'Area': area})
print(states,type(states))
# Out:
#             Population    Area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995 <class 'pandas.core.frame.DataFrame'>

# %%
states
# Out:
#             Population    Area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
type(states)
# Out:
# pandas.core.frame.DataFrame

# %%
states.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
states.values
# Out:
# array([[38332521,   423967],
#        [26448193,   695662],
#        [19651127,   141297],
#        [19552860,   170312],
#        [12882135,   149995]], dtype=int64)

# %%
states.columns
# Out:
# Index(['Population', 'Area'], dtype='object')

# %%
states.values.shape
# Out:
# (5, 2)

# %%
type(states.values)
# Out:
# numpy.ndarray

# %%
states['Area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: Area, dtype: int64

# %%
type(states['Area'])
# Out:
# pandas.core.series.Series

# %%
try:
    print(states['California'])
except KeyError as error:
    print("KeyError: ",error)
# Out:
# KeyError:  'California'

# %%
print(population,type(population))
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
states = pd.DataFrame({'Population': population, 'Area': area})
states
# Out:
#             Population    Area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %% [markdown]
# ## NumPy Array → Pandas DataFrame conversion

# %%
A = np.random.randn(5,3)
print(A,type(A))
dfA = pd.DataFrame(A)
dfA
# Out:
# [[-0.63876506  0.99760525 -0.46168385]
#  [-0.21183885  1.01821422 -1.17687026]
#  [-0.15665584 -0.10478758 -1.46103951]
#  [ 0.52842288 -2.04920839 -1.11326048]
#  [ 0.6404884  -0.36134609  0.50776398]] <class 'numpy.ndarray'>
#           0         1         2
# 0 -0.638765  0.997605 -0.461684
# 1 -0.211839  1.018214 -1.176870
# 2 -0.156656 -0.104788 -1.461040
# 3  0.528423 -2.049208 -1.113260
# 4  0.640488 -0.361346  0.507764

# %%
dfA.columns = ['a','b','c']
dfA.index = [i**2 for i in range(1,6)  ]
dfA
# Out:
#            a         b         c
# 1  -0.638765  0.997605 -0.461684
# 4  -0.211839  1.018214 -1.176870
# 9  -0.156656 -0.104788 -1.461040
# 16  0.528423 -2.049208 -1.113260
# 25  0.640488 -0.361346  0.507764

# %% [markdown]
# ## List Comprehension -> DataFrame

# %%
data = [{'a': i, 'b': 2 * i} for i in range(3)]
data
# Out:
# [{'a': 0, 'b': 0}, {'a': 1, 'b': 2}, {'a': 2, 'b': 4}]

# %%
type(data)
# Out:
# list

# %%
type(data[0])
# Out:
# dict

# %%
df = pd.DataFrame(data)
df
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %%
#  From simple list 

data = [5,10,15,20,25]
df = pd.DataFrame(data)
df
# Out:
#     0
# 0   5
# 1  10
# 2  15
# 3  20
# 4  25

# %%
data = [5,10,15,20,25]
df = pd.DataFrame(data , columns = ['Marks'])
df
# Out:
#    Marks
# 0      5
# 1     10
# 2     15
# 3     20
# 4     25

# %%
data = pd.read_csv('president_heights.csv')
data
# Out:
#     order                    name  height(cm)
# 0       1       George Washington         189
# 1       2              John Adams         170
# 2       3        Thomas Jefferson         189
# 3       4           James Madison         163
# 4       5            James Monroe         183
# 5       6       John Quincy Adams         171
# 6       7          Andrew Jackson         185
# 7       8        Martin Van Buren         168
# 8       9  William Henry Harrison         173
# 9      10              John Tyler         183
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 12     13        Millard Fillmore         175
# 13     14         Franklin Pierce         178
# 14     15          James Buchanan         183
# 15     16         Abraham Lincoln         193
# 16     17          Andrew Johnson         178
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# 19     20       James A. Garfield         183
# 20     21       Chester A. Arthur         183
# 21     23       Benjamin Harrison         168
# 22     25        William McKinley         170
# 23     26      Theodore Roosevelt         178
# 24     27     William Howard Taft         182
# 25     28          Woodrow Wilson         180
# 26     29       Warren G. Harding         183
# 27     30         Calvin Coolidge         178
# 28     31          Herbert Hoover         182
# 29     32   Franklin D. Roosevelt         188
# 30     33         Harry S. Truman         175
# 31     34    Dwight D. Eisenhower         179
# 32     35         John F. Kennedy         183
# 33     36       Lyndon B. Johnson         193
# 34     37           Richard Nixon         182
# 35     38             Gerald Ford         183
# 36     39            Jimmy Carter         177
# 37     40           Ronald Reagan         185
# 38     41       George H. W. Bush         188
# 39     42            Bill Clinton         188
# 40     43          George W. Bush         182
# 41     44            Barack Obama         185
# 42     45            Donald Trump         188

# %%
# @title order vs height(cm)

from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['order']
  ys = series['height(cm)']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = data.sort_values('order', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('order')
_ = plt.ylabel('height(cm)')

# %%
pd.DataFrame([{'a': 1, 'b': 2}, {'b': 3, 'c': 4}])
# Out:
#      a  b    c
# 0  1.0  2  NaN
# 1  NaN  3  4.0

# %%
dfA.columns
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
dfA.columns = ['a','b','c']
dfA.index = [i**2 for i in range(1,6)  ]
dfA
# Out:
#            a         b         c
# 1  -0.638765  0.997605 -0.461684
# 4  -0.211839  1.018214 -1.176870
# 9  -0.156656 -0.104788 -1.461040
# 16  0.528423 -2.049208 -1.113260
# 25  0.640488 -0.361346  0.507764

# %% [markdown]
# ## Indexing

# %%
area = pd.Series( {'California': 423967, 'Texas': 695662, 'New York': 141297, 'Florida': 170312, 'Illinois': 149995})
population = pd.Series({'California': 38332521, 'Texas': 26448193, 'New York': 19651127, 'Florida': 19552860, 'Illinois': 12882135})
states = pd.DataFrame({'Population': population, 'Area': area})
states
# Out:
#             Population    Area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %%
# @title Population vs Area

from matplotlib import pyplot as plt
states.plot(kind='scatter', x='Population', y='Area', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
states['Area']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: Area, dtype: int64

# %%
states['Area']['Texas']
# Out:
# 695662

# %%
states.iloc[:2]
# Out:
#             Population    Area
# California    38332521  423967
# Texas         26448193  695662

# %%
states.iloc[:2,0]
# Out:
# California    38332521
# Texas         26448193
# Name: Population, dtype: int64

# %%
states.loc[:'New York']
# Out:
#             Population    Area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297

# %%
states.loc[:,'Population':]
# Out:
#             Population    Area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19552860  170312
# Illinois      12882135  149995

# %% [markdown]
# # Questions & Exersize

# %% [markdown]
# **1. Series:**
#    - Create a Pandas Series with the following data: [10, 20, 30, 40, 50].
#    - Access the third element of the Series.
#    - What is the data type of the Series?

# %%
import pandas as pd 
import numpy as np

# %%
data = pd.Series([10, 20, 30, 40, 50])
data
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
data[2]
# Out:
# 30

# %%
type(data)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **2. DataFrames:**
#    - Create a Pandas DataFrame with two columns: 'Name' and 'Age'.
#    - Add three rows to the DataFrame with the following data:
#      - Name: 'Alice', Age: 25
#      - Name: 'Bob', Age: 30
#      - Name: 'Charlie', Age: 35
#    - Access the 'Age' column of the DataFrame.
#    - What is the shape of the DataFrame?

# %%
import pandas as pd

# %%
dfn =  pd.DataFrame({

    'name' : ['Alice' , 'Bob' , 'Charlie'],
    'age' : [25,30,35,]
})
dfn
# Out:
#       name  age
# 0    Alice   25
# 1      Bob   30
# 2  Charlie   35

# %%
#Access the 'Age' column of the DataFrame.

dfn['age']
# Out:
# 0    25
# 1    30
# 2    35
# Name: age, dtype: int64

# %%
# What is the shape of the DataFrame?

dfn.shape
# Out:
# (3, 2)

# %% [markdown]
# **3. Indexing:**
#    - Using the DataFrame from question 2, access the row with the name 'Bob' using `loc`.
#    - Access the age of 'Alice' using `iloc`.

# %%
# Using the DataFrame from question 2, access the row with the name 'Bob' using loc.

dfn = dfn.set_index('name')
dfn.loc['Bob']
# Out:
# age    30
# Name: Bob, dtype: int64

# %%
# Access the age of 'Alice' using iloc.

dfn['age'].iloc[0]
# Out:
# 25

# %% [markdown]
# **4. File I/O:**
#    - Read the 'president_heights.csv' file into a DataFrame.
#    - What is the average height of the presidents?
#    - What is the name of the tallest president?

# %%
df = pd.read_csv('president_heights.csv')
df
# Out:
#     order                    name  height(cm)
# 0       1       George Washington         189
# 1       2              John Adams         170
# 2       3        Thomas Jefferson         189
# 3       4           James Madison         163
# 4       5            James Monroe         183
# 5       6       John Quincy Adams         171
# 6       7          Andrew Jackson         185
# 7       8        Martin Van Buren         168
# 8       9  William Henry Harrison         173
# 9      10              John Tyler         183
# 10     11           James K. Polk         173
# 11     12          Zachary Taylor         173
# 12     13        Millard Fillmore         175
# 13     14         Franklin Pierce         178
# 14     15          James Buchanan         183
# 15     16         Abraham Lincoln         193
# 16     17          Andrew Johnson         178
# 17     18        Ulysses S. Grant         173
# 18     19     Rutherford B. Hayes         174
# 19     20       James A. Garfield         183
# 20     21       Chester A. Arthur         183
# 21     23       Benjamin Harrison         168
# 22     25        William McKinley         170
# 23     26      Theodore Roosevelt         178
# 24     27     William Howard Taft         182
# 25     28          Woodrow Wilson         180
# 26     29       Warren G. Harding         183
# 27     30         Calvin Coolidge         178
# 28     31          Herbert Hoover         182
# 29     32   Franklin D. Roosevelt         188
# 30     33         Harry S. Truman         175
# 31     34    Dwight D. Eisenhower         179
# 32     35         John F. Kennedy         183
# 33     36       Lyndon B. Johnson         193
# 34     37           Richard Nixon         182
# 35     38             Gerald Ford         183
# 36     39            Jimmy Carter         177
# 37     40           Ronald Reagan         185
# 38     41       George H. W. Bush         188
# 39     42            Bill Clinton         188
# 40     43          George W. Bush         182
# 41     44            Barack Obama         185
# 42     45            Donald Trump         188

# %%
avg_height = df['height(cm)'].mean()
avg_height
# Out:
# 179.93023255813952

# %%
# What is the name of the tallest president?

df.loc[df['height(cm)'].idxmax(), 'name']
# Out:
# 'Abraham Lincoln'

# %% [markdown]
# **5. Advanced:**
#    - Create a DataFrame with three columns: 'A', 'B', and 'C'.
#    - Fill the DataFrame with random numbers.
#    - Calculate the mean of each column.
#    - Add a new column 'D' which is the sum of columns 'A' and 'B'.
#    - Sort the DataFrame by column 'D' in descending order.

# %%
# Create a DataFrame with three columns: 'A', 'B', and 'C'.
# Fill the DataFrame with random numbers.


import numpy as np 
x = np.random.randn(3,3)
dfx = pd.DataFrame(x)
dfx
# Out:
#           0         1         2
# 0  1.792059  1.075156  0.793555
# 1  0.933157  1.541316  1.099681
# 2  0.229650 -1.063559 -0.736175

# %%
dfx.columns = ['A','B','C']
dfx
# Out:
#           A         B         C
# 0  1.792059  1.075156  0.793555
# 1  0.933157  1.541316  1.099681
# 2  0.229650 -1.063559 -0.736175

# %%
# Mean 

dfx.mean()
# Out:
# A    0.984955
# B    0.517638
# C    0.385687
# dtype: float64

# %%
dfx['A'].mean()
# Out:
# 0.9849551280089769

# %%
dfx['B'].mean()
# Out:
# 0.5176376453429632

# %%
dfx['A'].mean()
# Out:
# 0.9849551280089769

# %%
# Add a new column 'D' which is the sum of columns 'A' and 'B'.

dfx['D'] = dfx['A'] + dfx['B']
dfx['D']
# Out:
# 0    2.867215
# 1    2.474473
# 2   -0.833909
# Name: D, dtype: float64

# %%
dfx
# Out:
#           A         B         C         D
# 0  1.792059  1.075156  0.793555  2.867215
# 1  0.933157  1.541316  1.099681  2.474473
# 2  0.229650 -1.063559 -0.736175 -0.833909

# %%
dfx = dfx.sort_values(by='D', ascending=False)
dfx
# Out:
#           A         B         C         D
# 0  1.792059  1.075156  0.793555  2.867215
# 1  0.933157  1.541316  1.099681  2.474473
# 2  0.229650 -1.063559 -0.736175 -0.833909
