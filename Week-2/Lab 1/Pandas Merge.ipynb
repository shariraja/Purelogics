# %% [markdown]
# # <font color="purple"><h3 align="center">Pandas Merge Tutorial</h3></font>

# %%
import pandas as pd
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
df3 = pd.merge(df1 , df2 , on = 'city')
df3
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %% [markdown]
# ## <font color='blue'>Type Of DataBase Joins</font>

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando", "baltimore"],
    "temperature": [21,14,35, 38],
})
df1
# Out:
#         city  temperature
# 0   new york           22
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
df3=pd.merge(df1,df2,on="city",how="inner")
df3
# Out:
#        city  temperature  humidity
# 0  new york           22        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df3=pd.merge(df1,df2,on="city",how="outer")
df3
# Out:
#         city  temperature  humidity
# 0  baltimore           38       NaN
# 1    chicago           14      65.0
# 2   new york           21      68.0
# 3    orlando           35      75.0

# %%
df3=pd.merge(df1,df2,on="city",how="left")
df3
# Out:
#         city  temperature  humidity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35      75.0
# 3  baltimore           38       NaN

# %%
df3=pd.merge(df1,df2,on="city",how="right")
df3
# Out:
#        city  temperature  humidity
# 0   chicago           14        65
# 1  new york           21        68
# 2   orlando           35        75

# %% [markdown]
# ## <font color='blue'>indicator flag</font>

# %%
df3=pd.merge(df1,df2,on="city",how="outer",indicator=True)
df3
# Out:
#         city  temperature  humidity     _merge
# 0  baltimore           38       NaN  left_only
# 1    chicago           14      65.0       both
# 2   new york           21      68.0       both
# 3    orlando           35      75.0       both

# %% [markdown]
# ## <font color='blue'>suffixes</font>

# %%
 df4 = pd.DataFrame({
    "city": ["Lahore"],
    "temperature": [21],
})
df4
# Out:
#      city  temperature
# 0  Lahore           21

# %%
 df5 = pd.DataFrame({
    "city": ["Lahore"],
    "temperature": [21],
})
df5
# Out:
#      city  temperature
# 0  Lahore           21

# %%
df6 = pd.merge(df4 , df5 , on = 'city' , suffixes = ('Fisrt' , 'Second') )
df6
# Out:
#      city  temperatureFisrt  temperatureSecond
# 0  Lahore                21                 21

# %% [markdown]
# ## <font color='blue'>join</font>

# %%
df1 = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
})
df1.set_index('city',inplace=True)
df1
# Out:
#           temperature
# city
# new york           21
# chicago            14
# orlando            35

# %%
df2 = pd.DataFrame({
    "city": ["chicago","new york","orlando"],
    "humidity": [65,68,75],
})
df2.set_index('city',inplace=True)
df2
# Out:
#           humidity
# city
# chicago         65
# new york        68
# orlando         75

# %%
df1.join(df2,lsuffix='_l', rsuffix='_r')
# Out:
#           temperature  humidity
# city
# new york           21        68
# chicago            14        65
# orlando            35        75
